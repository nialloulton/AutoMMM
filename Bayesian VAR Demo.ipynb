# %%
from autoMMM.bayes import VARModel
import pymc as pm

# %% [markdown]
# # Simulate Data

# %%
import numpy as np
import pandas as pd

np.random.seed(123)

# Simulate some endogenous variables with 3 lags
n = 104
y1 = np.random.normal(size=n)
y2 = np.random.normal(size=n)
y3 = np.random.normal(size=n)
for i in range(3, n):
    y1[i] = -0.3 * y1[i - 1] - 0.6 * y1[i - 2] + 0.2 * y2[i - 2] + np.random.normal()
    y2[i] = -0.5 * y2[i - 1] + 0.2 * y3[i - 1] + np.random.normal()
    y3[i] = 0.7 * y3[i - 1] + 0.4 * y3[i - 2] - 0.3 * y3[i - 3] + np.random.normal()

# Simulate some exogenous variable
exog1 = np.random.normal(size=n)

# Put everything in pandas DataFrames
endog_df = pd.DataFrame({"x": y1, "Awareness": y2, "Long-Term Base": y3})
endog_df = endog_df.set_index(pd.date_range(start="2022-01-01", periods=n, freq="D"))

exog_df = pd.DataFrame({"Media": exog1})
exog_df = exog_df.set_index(pd.date_range(start="2022-01-01", periods=n, freq="D"))

# %% [markdown]
# # Specify the VAR parameters & priors

# %%
# Test VARModel
n_lags = 3
n_eqs = 3
priors = {
    "lag_coefs": {"mu": 0, "sigma": 0.1},
    "alpha": {"mu": 0, "sigma": 0.1},
    "coefs": {"mu": 0, "sigma": 0.1},
    "noise_chol": {"eta": 2, "sigma": 0.1},
    "noise": {"sigma": 1},
}

# %% [markdown]
# # Build the model & fit

# %%
model = VARModel(n_lags, n_eqs, endog_df, priors, exog_df=exog_df, mv_norm=False, prior_checks=False)
idata = model.fit(draws=2000, tune=500, target_accept=0.9)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [lag_coefs, alpha, exog_coefs, noise]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='10000' class='' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10000/10000 00:24&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 500 tune and 2_000 draw iterations (2_000 + 8_000 draws total) took 42 seconds.
# Sampling: [obs]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='8000' class='' max='8000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [8000/8000 00:00&lt;00:00]
#     </div>

# %% [markdown]
# # Compute Impulse Response Functions

# %%
# Compute and plot impulse response function
irf_df = model.impulse_response_function(num_periods=10, shock_var=1, shock_magnitude=1, cumsum=True, plot=False)

# %%
irf_df
# Out:
#            x  Awareness  Long-Term Base
# 0   0.000000   1.000000        0.000000
# 1  -0.008682   0.908152        0.052692
# 2  -0.006731   0.919713        0.059225
# 3  -0.007045   0.918940        0.061334
# 4  -0.006996   0.919135        0.061750
# 5  -0.007003   0.919138        0.061853
# 6  -0.007002   0.919144        0.061876
# 7  -0.007002   0.919144        0.061881
# 8  -0.007002   0.919144        0.061882
# 9  -0.007002   0.919144        0.061883
# 10 -0.007002   0.919144        0.061883

# %% [markdown]
# # Inspect model coefficients

# %%
pm.summary(idata, var_names=["lag_coefs"])
# Out:
#                                                mean     sd  hdi_3%  hdi_97%
# lag_coefs[x, 1, x]                           -0.179  0.070  -0.318   -0.053  \
# lag_coefs[x, 1, Awareness]                    0.004  0.064  -0.116    0.123
# lag_coefs[x, 1, Long-Term Base]              -0.072  0.063  -0.186    0.049
# lag_coefs[x, 2, x]                           -0.274  0.069  -0.398   -0.140
# lag_coefs[x, 2, Awareness]                    0.050  0.069  -0.080    0.177
# lag_coefs[x, 2, Long-Term Base]               0.071  0.068  -0.059    0.199
# lag_coefs[x, 3, x]                            0.100  0.068  -0.026    0.227
# lag_coefs[x, 3, Awareness]                   -0.080  0.068  -0.206    0.046
# lag_coefs[x, 3, Long-Term Base]               0.008  0.062  -0.103    0.131
# lag_coefs[Awareness, 1, x]                   -0.047  0.074  -0.182    0.097
# lag_coefs[Awareness, 1, Awareness]           -0.302  0.074  -0.440   -0.165
# lag_coefs[Awareness, 1, Long-Term Base]       0.034  0.067  -0.088    0.165
# lag_coefs[Awareness, 2, x]                   -0.023  0.072  -0.158    0.113
# lag_coefs[Awareness, 2, Awareness]            0.054  0.074  -0.084    0.190
# lag_coefs[Awareness, 2, Long-Term Base]       0.050  0.073  -0.081    0.190
# lag_coefs[Awareness, 3, x]                   -0.027  0.073  -0.159    0.113
# lag_coefs[Awareness, 3, Awareness]           -0.028  0.072  -0.163    0.109
# lag_coefs[Awareness, 3, Long-Term Base]       0.078  0.068  -0.051    0.207
# lag_coefs[Long-Term Base, 1, x]               0.043  0.074  -0.098    0.181
# lag_coefs[Long-Term Base, 1, Awareness]       0.100  0.070  -0.031    0.228
# lag_coefs[Long-Term Base, 1, Long-Term Base]  0.447  0.071   0.313    0.578
# lag_coefs[Long-Term Base, 2, x]               0.036  0.071  -0.099    0.165
# lag_coefs[Long-Term Base, 2, Awareness]       0.104  0.074  -0.037    0.235
# lag_coefs[Long-Term Base, 2, Long-Term Base]  0.183  0.073   0.042    0.317
# lag_coefs[Long-Term Base, 3, x]               0.010  0.074  -0.131    0.148
# lag_coefs[Long-Term Base, 3, Awareness]      -0.046  0.070  -0.173    0.091
# lag_coefs[Long-Term Base, 3, Long-Term Base]  0.032  0.068  -0.102    0.155
#
#                                               mcse_mean  mcse_sd  ess_bulk
# lag_coefs[x, 1, x]                                0.001    0.000   13500.0  \
# lag_coefs[x, 1, Awareness]                        0.001    0.001   15658.0
# lag_coefs[x, 1, Long-Term Base]                   0.001    0.000   14016.0
# lag_coefs[x, 2, x]                                0.001    0.000   13926.0
# lag_coefs[x, 2, Awareness]                        0.001    0.001   12485.0
# lag_coefs[x, 2, Long-Term Base]                   0.001    0.001   14226.0
# lag_coefs[x, 3, x]                                0.001    0.000   15721.0
# lag_coefs[x, 3, Awareness]                        0.001    0.001   14539.0
# lag_coefs[x, 3, Long-Term Base]                   0.001    0.001   14979.0
# lag_coefs[Awareness, 1, x]                        0.001    0.001   12987.0
# lag_coefs[Awareness, 1, Awareness]                0.001    0.000   14154.0
# lag_coefs[Awareness, 1, Long-Term Base]           0.001    0.001   12997.0
# lag_coefs[Awareness, 2, x]                        0.001    0.001   14666.0
# lag_coefs[Awareness, 2, Awareness]                0.001    0.001   12783.0
# lag_coefs[Awareness, 2, Long-Term Base]           0.001    0.001   13170.0
# lag_coefs[Awareness, 3, x]                        0.001    0.001   13861.0
# lag_coefs[Awareness, 3, Awareness]                0.001    0.001   14129.0
# lag_coefs[Awareness, 3, Long-Term Base]           0.001    0.001   15366.0
# lag_coefs[Long-Term Base, 1, x]                   0.001    0.001   13025.0
# lag_coefs[Long-Term Base, 1, Awareness]           0.001    0.001   14552.0
# lag_coefs[Long-Term Base, 1, Long-Term Base]      0.001    0.000   12963.0
# lag_coefs[Long-Term Base, 2, x]                   0.001    0.001   15279.0
# lag_coefs[Long-Term Base, 2, Awareness]           0.001    0.001   14099.0
# lag_coefs[Long-Term Base, 2, Long-Term Base]      0.001    0.000   15525.0
# lag_coefs[Long-Term Base, 3, x]                   0.001    0.001   14844.0
# lag_coefs[Long-Term Base, 3, Awareness]           0.001    0.001   15511.0
# lag_coefs[Long-Term Base, 3, Long-Term Base]      0.001    0.001   13208.0
#
#                                               ess_tail  r_hat
# lag_coefs[x, 1, x]                              6499.0    1.0
# lag_coefs[x, 1, Awareness]                      6469.0    1.0
# lag_coefs[x, 1, Long-Term Base]                 6388.0    1.0
# lag_coefs[x, 2, x]                              6435.0    1.0
# lag_coefs[x, 2, Awareness]                      6365.0    1.0
# lag_coefs[x, 2, Long-Term Base]                 6136.0    1.0
# lag_coefs[x, 3, x]                              6654.0    1.0
# lag_coefs[x, 3, Awareness]                      6038.0    1.0
# lag_coefs[x, 3, Long-Term Base]                 6196.0    1.0
# lag_coefs[Awareness, 1, x]                      6154.0    1.0
# lag_coefs[Awareness, 1, Awareness]              6835.0    1.0
# lag_coefs[Awareness, 1, Long-Term Base]         5770.0    1.0
# lag_coefs[Awareness, 2, x]                      5810.0    1.0
# lag_coefs[Awareness, 2, Awareness]              5766.0    1.0
# lag_coefs[Awareness, 2, Long-Term Base]         5985.0    1.0
# lag_coefs[Awareness, 3, x]                      6297.0    1.0
# lag_coefs[Awareness, 3, Awareness]              6051.0    1.0
# lag_coefs[Awareness, 3, Long-Term Base]         5667.0    1.0
# lag_coefs[Long-Term Base, 1, x]                 5997.0    1.0
# lag_coefs[Long-Term Base, 1, Awareness]         6225.0    1.0
# lag_coefs[Long-Term Base, 1, Long-Term Base]    6139.0    1.0
# lag_coefs[Long-Term Base, 2, x]                 6184.0    1.0
# lag_coefs[Long-Term Base, 2, Awareness]         6754.0    1.0
# lag_coefs[Long-Term Base, 2, Long-Term Base]    6749.0    1.0
# lag_coefs[Long-Term Base, 3, x]                 6160.0    1.0
# lag_coefs[Long-Term Base, 3, Awareness]         6241.0    1.0
# lag_coefs[Long-Term Base, 3, Long-Term Base]    5971.0    1.0
