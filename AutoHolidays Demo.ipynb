# %%
from autoMMM.autoholidays import HolidayExtractor

# %%
# Usage:
country = 'US'
start_date = '2023-01-01'
end_date = '2023-12-31'
week_start = 'Monday'

holiday_extractor = HolidayExtractor(country, start_date, end_date)

# Get holidays for a specific region
region = 'CA'
regional_holidays = holiday_extractor.get_holidays_by_region(region)

# Generate timeseries with custom holiday list
custom_holiday_list = ['New Year\'s Day', 'Christmas Day', 'Easter Sunday', 'Eid al-Fitr', 'Diwali']
weekly_timeseries_df = holiday_extractor.generate_timeseries(week_start=week_start, custom_holiday_list=custom_holiday_list)

weekly_timeseries_df
# Out:
#    Week Commencing  Is Holiday  Custom Holiday  Weeks Since Last Holiday
# 0       2022-12-26           1               1                         0
# 1       2023-01-02           1               0                         1
# 2       2023-01-09           0               0                         0
# 3       2023-01-16           1               0                         2
# 4       2023-01-23           0               0                         0
# 5       2023-01-30           0               0                         0
# 6       2023-02-06           0               0                         0
# 7       2023-02-13           0               0                         0
# 8       2023-02-20           1               0                         5
# 9       2023-02-27           0               0                         0
# 10      2023-03-06           0               0                         0
# 11      2023-03-13           0               0                         0
# ...
